# %% [markdown]
# <a href="https://colab.research.google.com/github/KhushiiAgarwal/AI/blob/main/Azure_openAI.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import json
from tabulate import tabulate

# %%
def process_json_tables(json_file=None, json_data=None):
    """
    Process all tables from a JSON file or string containing table data.

    Parameters:
    json_file (str, optional): Path to JSON file
    json_data (str, optional): JSON string data

    Returns:
    dict: Dictionary of formatted tables and metadata
    """
    # Load the data
    if json_file:
        with open(json_file, 'r') as f:
            data = json.load(f)
    elif json_data:
        data = json.loads(json_data)
    else:
        raise ValueError("Either json_file or json_data must be provided")

    # Check if 'tables' key exists
    if 'tables' not in data:
        raise KeyError("The JSON data does not contain a 'tables' key")

    # Extract and process all tables
    result = {}
    tables = data['tables']
    result['table_count'] = len(tables)

    # Dictionary to store formatted tables
    formatted_tables = {}
    table_metadata = {}

    print(f"Found {len(tables)} tables in the document.")

    # Process each table
    for i, table in enumerate(tables):
        table_id = table.get('table_id', f'table_{i}')

        # Basic formatting
        df = format_table_from_json(table)

        # Advanced formatting with header info
        df_with_headers, header_positions = format_table_with_headers(table)

        # Store results
        formatted_tables[table_id] = {
            'basic': df,
            'with_headers': df_with_headers
        }

        table_metadata[table_id] = {
            'row_count': table['row_count'],
            'column_count': table['column_count'],
            'cell_count': len(table['cells']),
            'header_positions': list(header_positions)
        }

        # Print basic info about the table
        print(f"\nTable {i+3}: {table_id}")
        print(f"Dimensions: {table['row_count']} rows x {table['column_count']} columns")
        print(f"Cell count: {len(table['cells'])}")
        print(f"Has headers: {len(header_positions) > 0}")

    # Store all processed data
    result['formatted_tables'] = formatted_tables
    result['table_metadata'] = table_metadata

    return result

# %%
def format_table_from_json(table_data):
    """
    Format table data from a JSON structure into a pandas DataFrame.

    Parameters:
    table_data (dict): JSON structure containing table information

    Returns:
    pandas.DataFrame: Formatted table
    """
    # Extract row and column counts
    row_count = table_data["row_count"]
    column_count = table_data["column_count"]

    # Create an empty DataFrame with the right dimensions
    df = pd.DataFrame(np.empty((row_count, column_count), dtype=object))

    # Fill the DataFrame with content from the cells
    for cell in table_data["cells"]:
        row_idx = cell["row_index"]
        col_idx = cell["column_index"]
        content = cell["content"]
        df.iloc[row_idx, col_idx] = content

    # Replace None/NaN values with empty strings
    df = df.fillna('')

    return df

# %%
def format_table_with_headers(table_data):
    """
    Format table data with header information from a JSON structure into a pandas DataFrame.

    Parameters:
    table_data (dict): JSON structure containing table information with 'kind' field

    Returns:
    tuple: (DataFrame, header_positions) where header_positions is a set of (row, col) tuples
    """
    # Extract row and column counts
    row_count = table_data["row_count"]
    column_count = table_data["column_count"]

    # Create an empty DataFrame with the right dimensions
    df = pd.DataFrame(np.empty((row_count, column_count), dtype=object))

    # Track header positions
    header_positions = set()

    # Fill the DataFrame with content from the cells
    for cell in table_data["cells"]:
        row_idx = cell["row_index"]
        col_idx = cell["column_index"]
        content = cell["content"]

        # Store the cell content
        df.iloc[row_idx, col_idx] = content

        # Check if the cell is a header (look for 'kind' field that contains 'header')
        if "kind" in cell and "header" in cell["kind"].lower():
            header_positions.add((row_idx, col_idx))

    # Replace None/NaN values with empty strings
    df = df.fillna('')

    return df, header_positions

# %%
# def display_dataframe(df, header_positions=None):
#     """
#     Display a DataFrame with formatted headers.

#     Parameters:
#     df (pandas.DataFrame): The DataFrame to display
#     header_positions (set, optional): Set of (row, col) tuples indicating header positions
#     """
#     # Try to use tabulate for better console display if available
#     try:
#         if header_positions:
#             # Create a copy with bold headers for display
#             display_data = []
#             for row_idx in range(df.shape[0]):
#                 row_data = []
#                 for col_idx in range(df.shape[3]):
#                     value = df.iloc[row_idx, col_idx]
#                     if (row_idx, col_idx) in header_positions:
#                         # Mark headers with asterisks for emphasis
#                         row_data.append(f"**{value}**")
#                     else:
#                         row_data.append(value)
#                 display_data.append(row_data)

#             print(tabulate(display_data, tablefmt='grid'))
#         else:
#             print(tabulate(df, headers='keys', tablefmt='grid'))
#     except (ImportError, NameError):
#         # Fall back to standard display if tabulate is not available
#         print(df)

# %%
def display_dataframe(df, header_positions=None):
    """
    Display a DataFrame with formatted headers.

    Parameters:
    df (pandas.DataFrame): The DataFrame to display
    header_positions (set, optional): Set of (row, col) tuples indicating header positions
    """
    # Try to use tabulate for better console display if available
    try:
        if header_positions:
            # Create a copy with bold headers for display
            display_data = []
            for row_idx in range(df.shape[0]):
                row_data = []
                # Use df.shape[1] to get the correct number of columns
                for col_idx in range(df.shape[1]):  # Changed from df.shape[3] to df.shape[1]
                    value = df.iloc[row_idx, col_idx]
                    if (row_idx, col_idx) in header_positions:
                        # Mark headers with asterisks for emphasis
                        row_data.append(f"**{value}**")
                    else:
                        row_data.append(value)
                display_data.append(row_data)

            print(tabulate(display_data, tablefmt='grid'))
        else:
            print(tabulate(df, headers='keys', tablefmt='grid'))
    except (ImportError, NameError):
        # Fall back to standard display if tabulate is not available
        print(df)

# %%
def extract_specific_page_tables(data, page_number):
    """
    Extract tables from a specific page in the document.

    Parameters:
    data (dict): Loaded JSON data with 'tables' key
    page_number (int): Page number to extract tables from

    Returns:
    list: List of tables from the specified page
    """
    if 'tables' not in data:
        raise KeyError("The JSON data does not contain a 'tables' key")

    page_id = f"page_{page_number}"
    filtered_tables = []

    for table in data['tables']:
        if 'table_id' in table and page_id in table['table_id']:
            filtered_tables.append(table)

    return filtered_tables

# %%
# Example usage:
if __name__ == "__main__":
    # Process the sample data
    data_file = r'/content/extracted_form_data_azure_form_recogn.json'  # Path to your JSON file
    with open(data_file, 'r') as f:
            data = json.load(f)
    sample_data=data
    results = process_json_tables(json_data=json.dumps(sample_data))
# Out:
# Found 274 tables in the document.
#
# Table 3: page_1_table_0
# Dimensions: 5 rows x 5 columns
# Cell count: 17
# Has headers: False
#
# Table 4: page_1_table_1
# Dimensions: 7 rows x 4 columns
# Cell count: 19
# Has headers: False
#
# Table 5: page_2_table_0
# Dimensions: 5 rows x 3 columns
# Cell count: 12
# Has headers: False
#
# Table 6: page_2_table_1
# Dimensions: 21 rows x 4 columns
# Cell count: 40
# Has headers: False
#
# Table 7: page_3_table_0
# Dimensions: 5 rows x 3 columns
# Cell count: 12
# Has headers: False
#
# Table 8: page_3_table_1
# Dimensions: 19 rows x 3 columns
# Cell count: 57
# Has headers: False
#
# Table 9: page_4_table_0
# Dimensions: 5 rows x 3 columns
# Cell count: 12
# Has headers: False
#
# Table 10: page_4_table_1
# Dimensions: 10 rows x 3 columns
# Cell count: 30
# Has headers: False
#
# Table 11: page_5_table_0
# Dimensions: 5 rows x 3 columns
# Cell count: 12
# Has headers: False
#
# Table 12: page_5_table_1
# Dimensions: 24 rows x 2 columns
# Cell count: 35
# Has headers: False
#
# Table 13: page_6_table_0
# Dimensions: 5 rows x 3 columns
# Cell count: 12
# Has headers: False
#
# Table 14: page_6_table_1
# Dimensions: 8 rows x 2 columns
# Cell count: 13
# Has headers: False
#
# Table 15: page_7_table_0
# Dimensions: 5 rows x 3 columns
# Cell count: 12
# Has headers: False
#
# Table 16: page_7_table_1
# Dimensions: 28 rows x 4 columns
# Cell count: 112
# Has headers: False
#
# Table 17: page_8_table_0
# Dimensions: 5 rows x 3 columns
# Cell count: 12
# Has headers: False
#
# Table 18: page_8_table_1
# Dimensions: 28 rows x 4 columns
# Cell count: 109
# Has headers: False
#
# Table 19: page_9_table_0
# Dimensions: 5 rows x 3 columns
# Cell count: 12
# Has headers: False
#
# Table 20: page_9_table_1
# Dimensions: 19 rows x 4 columns
# Cell count: 70
# Has headers: False
#
# Table 21: page_10_table_0
# Dimensions: 5 rows x 3 columns
# Cell count: 12
# Has headers: False
#
# Table 22: page_10_table_1
# Dimensions: 9 rows x 7 columns
# Cell count: 51
# Has headers: False
#
# Table 23: page_11_table_0
# Dimensions: 5 rows x 3 columns
# Cell count: 12
# Has headers: False
#
# Table 24: page_12_table_0
# Dimensions: 5 rows x 3 columns
# Cell count: 12
# Has headers: False
#
# Table 25: page_12_table_1
# Dimensions: 18 rows x 6 columns
# Cell count: 92
# Has headers: False
#
# Table 26: page_13_table_0
# Dimensions: 5 rows x 3 columns
# Cell count: 12
# Has headers: False
#
# Table 27: page_13_table_1
# Dimensions: 18 rows x 5 columns
# Cell count: 90
# Has headers: False
#
# Table 28: page_14_table_0
# Dimensions: 5 rows x 3 columns
# Cell count: 12
# Has headers: False
#
# Table 29: page_14_table_1
# Dimensions: 10 rows x 7 columns
# Cell count: 70
# Has headers: False
#
# Table 30: page_15_table_0
# Dimensions: 5 rows x 3 columns
# Cell count: 12
# Has headers: False
#
# Table 31: page_15_table_1
# Dimensions: 6 rows x 6 columns
# Cell count: 36
# Has headers: False
#
# Table 32: page_15_table_2
# Dimensions: 4 rows x 5 columns
# Cell count: 20
# Has headers: False
#
# Table 33: page_16_table_0
# Dimensions: 5 rows x 3 columns
# Cell count: 12
# Has headers: False
#
# Table 34: page_16_table_1
# Dimensions: 8 rows x 8 columns
# Cell count: 64
# Has headers: False
#
# Table 35: page_17_table_0
# Dimensions: 5 rows x 3 columns
# Cell count: 12
# Has headers: False
#
# Table 36: page_17_table_1
# Dimensions: 3 rows x 7 columns
# Cell count: 15
# Has headers: False
#
# Table 37: page_18_table_0
# Dimensions: 5 rows x 3 columns
# Cell count: 12
# Has headers: False
#
# Table 38: page_18_table_1
# Dimensions: 2 rows x 2 columns
# Cell count: 4
# Has headers: False
#
# Table 39: page_18_table_2
# Dimensions: 2 rows x 2 columns
# Cell count: 4
# Has headers: False
#
# Table 40: page_19_table_0
# Dimensions: 5 rows x 3 columns
# Cell count: 12
# Has headers: False
#
# Table 41: page_20_table_0
# Dimensions: 5 rows x 3 columns
# Cell count: 12
# Has headers: False
#
# Table 42: page_20_table_1
# Dimensions: 2 rows x 2 columns
# Cell count: 4
# Has headers: False
#
# Table 43: page_21_table_0
# Dimensions: 5 rows x 3 columns
# Cell count: 12
# Has headers: False
#
# Table 44: page_21_table_1
# Dimensions: 5 rows x 5 columns
# Cell count: 22
# Has headers: False
#
# Table 45: page_21_table_2
# Dimensions: 2 rows x 2 columns
# Cell count: 4
# Has headers: False
#
# Table 46: page_22_table_0
# Dimensions: 5 rows x 3 columns
# Cell count: 12
# Has headers: False
#
# Table 47: page_23_table_0
# Dimensions: 5 rows x 3 columns
# Cell count: 12
# Has headers: False
#
# Table 48: page_23_table_1
# Dimensions: 2 rows x 2 columns
# Cell count: 4
# Has headers: False
#
# Table 49: page_24_table_0
# Dimensions: 5 rows x 3 columns
# Cell count: 12
# Has headers: False
#
# Table 50: page_24_table_1
# Dimensions: 3 rows x 7 columns
# Cell count: 17
# Has headers: False
#
# Table 51: page_24_table_2
# Dimensions: 2 rows x 2 columns
# Cell count: 4
# Has headers: False
#
# Table 52: page_25_table_0
# Dimensions: 5 rows x 3 columns
# Cell count: 12
# Has headers: False
#
# Table 53: page_26_table_0
# Dimensions: 5 rows x 3 columns
# Cell count: 12
# Has headers: False
#
# Table 54: page_27_table_0
# Dimensions: 5 rows x 3 columns
# Cell count: 12
# Has headers: False
#
# Table 55: page_27_table_1
# Dimensions: 5 rows x 5 columns
# Cell count: 16
# Has headers: False
#
# Table 56: page_27_table_2
# Dimensions: 2 rows x 2 columns
# Cell count: 4
# Has headers: False
#
# Table 57: page_28_table_0
# Dimensions: 5 rows x 3 columns
# Cell count: 12
# Has headers: False
#
# Table 58: page_28_table_1
# Dimensions: 22 rows x 8 columns
# Cell count: 140
# Has headers: False
#
# Table 59: page_29_table_0
# Dimensions: 5 rows x 3 columns
# Cell count: 12
# Has headers: False
#
# Table 60: page_29_table_1
# Dimensions: 2 rows x 2 columns
# Cell count: 4
# Has headers: False
#
# Table 61: page_30_table_0
# Dimensions: 5 rows x 3 columns
# Cell count: 12
# Has headers: False
#
# Table 62: page_30_table_1
# Dimensions: 11 rows x 9 columns
# Cell count: 67
# Has headers: False
#
# Table 63: page_31_table_0
# Dimensions: 5 rows x 3 columns
# Cell count: 12
# Has headers: False
#
# Table 64: page_31_table_1
# Dimensions: 2 rows x 9 columns
# Cell count: 18
# Has headers: False
#
# Table 65: page_31_table_2
# Dimensions: 3 rows x 9 columns
# Cell count: 27
# Has headers: False
#
# Table 66: page_32_table_0
# Dimensions: 5 rows x 3 columns
# Cell count: 12
# Has headers: False
#
# Table 67: page_32_table_1
# Dimensions: 11 rows x 3 columns
# Cell count: 19
# Has headers: False
#
# Table 68: page_33_table_0
# Dimensions: 5 rows x 3 columns
# Cell count: 12
# Has headers: False
#
# Table 69: page_33_table_1
# Dimensions: 5 rows x 9 columns
# Cell count: 37
# Has headers: False
#
# Table 70: page_34_table_0
# Dimensions: 5 rows x 3 columns
# Cell count: 12
# Has headers: False
#
# Table 71: page_34_table_1
# Dimensions: 7 rows x 2 columns
# Cell count: 13
# Has headers: False
#
# Table 72: page_35_table_0
# Dimensions: 5 rows x 3 columns
# Cell count: 12
# Has headers: False
#
# Table 73: page_35_table_1
# Dimensions: 6 rows x 8 columns
# Cell count: 48
# Has headers: False
#
# Table 74: page_36_table_0
# Dimensions: 5 rows x 3 columns
# Cell count: 12
# Has headers: False
#
# Table 75: page_36_table_1
# Dimensions: 3 rows x 7 columns
# Cell count: 15
# Has headers: False
#
# Table 76: page_37_table_0
# Dimensions: 5 rows x 3 columns
# Cell count: 12
# Has headers: False
#
# Table 77: page_37_table_1
# Dimensions: 3 rows x 6 columns
# Cell count: 13
# Has headers: False
#
# Table 78: page_38_table_0
# Dimensions: 5 rows x 3 columns
# Cell count: 12
# Has headers: False
#
# Table 79: page_38_table_1
# Dimensions: 18 rows x 5 columns
# Cell count: 90
# Has headers: False
#
# Table 80: page_39_table_0
# Dimensions: 5 rows x 3 columns
# Cell count: 12
# Has headers: False
#
# Table 81: page_39_table_1
# Dimensions: 17 rows x 5 columns
# Cell count: 85
# Has headers: False
#
# Table 82: page_40_table_0
# Dimensions: 5 rows x 3 columns
# Cell count: 12
# Has headers: False
#
# Table 83: page_40_table_1
# Dimensions: 11 rows x 2 columns
# Cell count: 13
# Has headers: False
#
# Table 84: page_41_table_0
# Dimensions: 5 rows x 3 columns
# Cell count: 12
# Has headers: False
#
# Table 85: page_41_table_1
# Dimensions: 4 rows x 9 columns
# Cell count: 30
# Has headers: False
#
# Table 86: page_41_table_2
# Dimensions: 5 rows x 2 columns
# Cell count: 8
# Has headers: False
#
# Table 87: page_42_table_0
# Dimensions: 5 rows x 3 columns
# Cell count: 12
# Has headers: False
#
# Table 88: page_42_table_1
# Dimensions: 4 rows x 9 columns
# Cell count: 30
# Has headers: False
#
# Table 89: page_42_table_2
# Dimensions: 3 rows x 2 columns
# Cell count: 6
# Has headers: False
#
# Table 90: page_43_table_0
# Dimensions: 5 rows x 3 columns
# Cell count: 12
# Has headers: False
#
# Table 91: page_43_table_1
# Dimensions: 2 rows x 7 columns
# Cell count: 14
# Has headers: False
#
# Table 92: page_43_table_2
# Dimensions: 5 rows x 6 columns
# Cell count: 26
# Has headers: False
#
# Table 93: page_43_table_3
# Dimensions: 4 rows x 2 columns
# Cell count: 7
# Has headers: False
#
# Table 94: page_44_table_0
# Dimensions: 5 rows x 3 columns
# Cell count: 12
# Has headers: False
#
# Table 95: page_44_table_1
# Dimensions: 5 rows x 6 columns
# Cell count: 26
# Has headers: False
#
# Table 96: page_44_table_2
# Dimensions: 3 rows x 2 columns
# Cell count: 6
# Has headers: False
#
# Table 97: page_45_table_0
# Dimensions: 5 rows x 3 columns
# Cell count: 12
# Has headers: False
#
# Table 98: page_45_table_1
# Dimensions: 10 rows x 5 columns
# Cell count: 36
# Has headers: False
#
# Table 99: page_46_table_0
# Dimensions: 5 rows x 3 columns
# Cell count: 12
# Has headers: False
#
# Table 100: page_46_table_1
# Dimensions: 4 rows x 7 columns
# Cell count: 24
# Has headers: False
#
# Table 101: page_46_table_2
# Dimensions: 2 rows x 7 columns
# Cell count: 14
# Has headers: False
#
# Table 102: page_47_table_0
# Dimensions: 5 rows x 3 columns
# Cell count: 12
# Has headers: False
#
# Table 103: page_47_table_1
# Dimensions: 5 rows x 6 columns
# Cell count: 30
# Has headers: False
#
# Table 104: page_48_table_0
# Dimensions: 5 rows x 3 columns
# Cell count: 12
# Has headers: False
#
# Table 105: page_48_table_1
# Dimensions: 3 rows x 5 columns
# Cell count: 15
# Has headers: False
#
# Table 106: page_49_table_0
# Dimensions: 5 rows x 3 columns
# Cell count: 12
# Has headers: False
#
# Table 107: page_49_table_1
# Dimensions: 2 rows x 5 columns
# Cell count: 10
# Has headers: False
#
# Table 108: page_50_table_0
# Dimensions: 5 rows x 3 columns
# Cell count: 12
# Has headers: False
#
# Table 109: page_50_table_1
# Dimensions: 3 rows x 6 columns
# Cell count: 18
# Has headers: False
#
# Table 110: page_51_table_0
# Dimensions: 5 rows x 3 columns
# Cell count: 12
# Has headers: False
#
# Table 111: page_51_table_1
# Dimensions: 3 rows x 6 columns
# Cell count: 18
# Has headers: False
#
# Table 112: page_52_table_0
# Dimensions: 5 rows x 3 columns
# Cell count: 12
# Has headers: False
#
# Table 113: page_52_table_1
# Dimensions: 3 rows x 6 columns
# Cell count: 18
# Has headers: False
#
# Table 114: page_53_table_0
# Dimensions: 5 rows x 3 columns
# Cell count: 12
# Has headers: False
#
# Table 115: page_53_table_1
# Dimensions: 4 rows x 6 columns
# Cell count: 19
# Has headers: False
#
# Table 116: page_54_table_0
# Dimensions: 5 rows x 3 columns
# Cell count: 12
# Has headers: False
#
# Table 117: page_54_table_1
# Dimensions: 6 rows x 6 columns
# Cell count: 21
# Has headers: False
#
# Table 118: page_55_table_0
# Dimensions: 5 rows x 3 columns
# Cell count: 12
# Has headers: False
#
# Table 119: page_55_table_1
# Dimensions: 5 rows x 6 columns
# Cell count: 25
# Has headers: False
#
# Table 120: page_56_table_0
# Dimensions: 5 rows x 3 columns
# Cell count: 12
# Has headers: False
#
# Table 121: page_56_table_1
# Dimensions: 16 rows x 9 columns
# Cell count: 45
# Has headers: False
#
# Table 122: page_57_table_0
# Dimensions: 5 rows x 3 columns
# Cell count: 12
# Has headers: False
#
# Table 123: page_58_table_0
# Dimensions: 5 rows x 3 columns
# Cell count: 12
# Has headers: False
#
# Table 124: page_58_table_1
# Dimensions: 6 rows x 7 columns
# Cell count: 32
# Has headers: False
#
# Table 125: page_59_table_0
# Dimensions: 5 rows x 3 columns
# Cell count: 12
# Has headers: False
#
# Table 126: page_59_table_1
# Dimensions: 6 rows x 5 columns
# Cell count: 30
# Has headers: False
#
# Table 127: page_59_table_2
# Dimensions: 4 rows x 5 columns
# Cell count: 20
# Has headers: False
#
# Table 128: page_60_table_0
# Dimensions: 5 rows x 3 columns
# Cell count: 12
# Has headers: False
#
# Table 129: page_60_table_1
# Dimensions: 2 rows x 2 columns
# Cell count: 4
# Has headers: False
#
# Table 130: page_60_table_2
# Dimensions: 9 rows x 5 columns
# Cell count: 45
# Has headers: False
#
# Table 131: page_61_table_0
# Dimensions: 5 rows x 3 columns
# Cell count: 12
# Has headers: False
#
# Table 132: page_61_table_1
# Dimensions: 9 rows x 4 columns
# Cell count: 36
# Has headers: False
#
# Table 133: page_62_table_0
# Dimensions: 5 rows x 3 columns
# Cell count: 12
# Has headers: False
#
# Table 134: page_62_table_1
# Dimensions: 21 rows x 5 columns
# Cell count: 105
# Has headers: False
#
# Table 135: page_63_table_0
# Dimensions: 5 rows x 3 columns
# Cell count: 12
# Has headers: False
#
# Table 136: page_63_table_1
# Dimensions: 13 rows x 5 columns
# Cell count: 65
# Has headers: False
#
# Table 137: page_64_table_0
# Dimensions: 5 rows x 3 columns
# Cell count: 12
# Has headers: False
#
# Table 138: page_64_table_1
# Dimensions: 4 rows x 9 columns
# Cell count: 30
# Has headers: False
#
# Table 139: page_64_table_2
# Dimensions: 3 rows x 2 columns
# Cell count: 6
# Has headers: False
#
# Table 140: page_65_table_0
# Dimensions: 5 rows x 3 columns
# Cell count: 12
# Has headers: False
#
# Table 141: page_65_table_1
# Dimensions: 18 rows x 2 columns
# Cell count: 33
# Has headers: False
#
# Table 142: page_66_table_0
# Dimensions: 5 rows x 3 columns
# Cell count: 12
# Has headers: False
#
# Table 143: page_66_table_1
# Dimensions: 3 rows x 7 columns
# Cell count: 15
# Has headers: False
#
# Table 144: page_66_table_2
# Dimensions: 5 rows x 6 columns
# Cell count: 26
# Has headers: False
#
# Table 145: page_66_table_3
# Dimensions: 4 rows x 2 columns
# Cell count: 8
# Has headers: False
#
# Table 146: page_67_table_0
# Dimensions: 5 rows x 3 columns
# Cell count: 12
# Has headers: False
#
# Table 147: page_67_table_1
# Dimensions: 4 rows x 6 columns
# Cell count: 20
# Has headers: False
#
# Table 148: page_67_table_2
# Dimensions: 2 rows x 7 columns
# Cell count: 14
# Has headers: False
#
# Table 149: page_68_table_0
# Dimensions: 5 rows x 3 columns
# Cell count: 12
# Has headers: False
#
# Table 150: page_68_table_1
# Dimensions: 4 rows x 7 columns
# Cell count: 22
# Has headers: False
#
# Table 151: page_68_table_2
# Dimensions: 3 rows x 5 columns
# Cell count: 11
# Has headers: False
#
# Table 152: page_68_table_3
# Dimensions: 5 rows x 7 columns
# Cell count: 35
# Has headers: False
#
# Table 153: page_69_table_0
# Dimensions: 5 rows x 3 columns
# Cell count: 12
# Has headers: False
#
# Table 154: page_69_table_1
# Dimensions: 5 rows x 7 columns
# Cell count: 29
# Has headers: False
#
# Table 155: page_70_table_0
# Dimensions: 5 rows x 3 columns
# Cell count: 12
# Has headers: False
#
# Table 156: page_70_table_1
# Dimensions: 7 rows x 6 columns
# Cell count: 42
# Has headers: False
#
# Table 157: page_71_table_0
# Dimensions: 5 rows x 3 columns
# Cell count: 12
# Has headers: False
#
# Table 158: page_71_table_1
# Dimensions: 10 rows x 6 columns
# Cell count: 55
# Has headers: False
#
# Table 159: page_72_table_0
# Dimensions: 5 rows x 3 columns
# Cell count: 12
# Has headers: False
#
# Table 160: page_72_table_1
# Dimensions: 22 rows x 5 columns
# Cell count: 110
# Has headers: False
#
# Table 161: page_73_table_0
# Dimensions: 5 rows x 3 columns
# Cell count: 12
# Has headers: False
#
# Table 162: page_73_table_1
# Dimensions: 20 rows x 5 columns
# Cell count: 92
# Has headers: False
#
# Table 163: page_74_table_0
# Dimensions: 5 rows x 3 columns
# Cell count: 12
# Has headers: False
#
# Table 164: page_74_table_1
# Dimensions: 11 rows x 5 columns
# Cell count: 55
# Has headers: False
#
# Table 165: page_75_table_0
# Dimensions: 5 rows x 3 columns
# Cell count: 12
# Has headers: False
#
# Table 166: page_75_table_1
# Dimensions: 11 rows x 4 columns
# Cell count: 44
# Has headers: False
#
# Table 167: page_76_table_0
# Dimensions: 5 rows x 3 columns
# Cell count: 12
# Has headers: False
#
# Table 168: page_76_table_1
# Dimensions: 4 rows x 6 columns
# Cell count: 20
# Has headers: False
#
# Table 169: page_76_table_2
# Dimensions: 3 rows x 2 columns
# Cell count: 6
# Has headers: False
#
# Table 170: page_76_table_3
# Dimensions: 5 rows x 6 columns
# Cell count: 26
# Has headers: False
#
# Table 171: page_76_table_4
# Dimensions: 3 rows x 2 columns
# Cell count: 6
# Has headers: False
#
# Table 172: page_77_table_0
# Dimensions: 5 rows x 3 columns
# Cell count: 12
# Has headers: False
#
# Table 173: page_77_table_1
# Dimensions: 5 rows x 6 columns
# Cell count: 26
# Has headers: False
#
# Table 174: page_77_table_2
# Dimensions: 3 rows x 2 columns
# Cell count: 6
# Has headers: False
#
# Table 175: page_77_table_3
# Dimensions: 4 rows x 6 columns
# Cell count: 20
# Has headers: False
#
# Table 176: page_77_table_4
# Dimensions: 3 rows x 2 columns
# Cell count: 6
# Has headers: False
#
# Table 177: page_78_table_0
# Dimensions: 5 rows x 3 columns
# Cell count: 12
# Has headers: False
#
# Table 178: page_78_table_1
# Dimensions: 2 rows x 6 columns
# Cell count: 12
# Has headers: False
#
# Table 179: page_78_table_2
# Dimensions: 13 rows x 7 columns
# Cell count: 69
# Has headers: False
#
# Table 180: page_79_table_0
# Dimensions: 5 rows x 3 columns
# Cell count: 12
# Has headers: False
#
# Table 181: page_79_table_1
# Dimensions: 2 rows x 3 columns
# Cell count: 6
# Has headers: False
#
# Table 182: page_79_table_2
# Dimensions: 5 rows x 4 columns
# Cell count: 20
# Has headers: False
#
# Table 183: page_80_table_0
# Dimensions: 5 rows x 3 columns
# Cell count: 12
# Has headers: False
#
# Table 184: page_81_table_0
# Dimensions: 5 rows x 3 columns
# Cell count: 12
# Has headers: False
#
# Table 185: page_81_table_1
# Dimensions: 7 rows x 10 columns
# Cell count: 48
# Has headers: False
#
# Table 186: page_82_table_0
# Dimensions: 5 rows x 3 columns
# Cell count: 12
# Has headers: False
#
# Table 187: page_82_table_1
# Dimensions: 2 rows x 5 columns
# Cell count: 10
# Has headers: False
#
# Table 188: page_83_table_0
# Dimensions: 5 rows x 3 columns
# Cell count: 12
# Has headers: False
#
# Table 189: page_83_table_1
# Dimensions: 15 rows x 5 columns
# Cell count: 71
# Has headers: False
#
# Table 190: page_84_table_0
# Dimensions: 5 rows x 3 columns
# Cell count: 12
# Has headers: False
#
# Table 191: page_84_table_1
# Dimensions: 14 rows x 5 columns
# Cell count: 70
# Has headers: False
#
# Table 192: page_85_table_0
# Dimensions: 5 rows x 3 columns
# Cell count: 12
# Has headers: False
#
# Table 193: page_85_table_1
# Dimensions: 2 rows x 10 columns
# Cell count: 20
# Has headers: False
#
# Table 194: page_85_table_2
# Dimensions: 7 rows x 5 columns
# Cell count: 25
# Has headers: False
#
# Table 195: page_86_table_0
# Dimensions: 5 rows x 3 columns
# Cell count: 12
# Has headers: False
#
# Table 196: page_86_table_1
# Dimensions: 3 rows x 4 columns
# Cell count: 9
# Has headers: False
#
# Table 197: page_86_table_2
# Dimensions: 11 rows x 10 columns
# Cell count: 101
# Has headers: False
#
# Table 198: page_87_table_0
# Dimensions: 5 rows x 3 columns
# Cell count: 12
# Has headers: False
#
# Table 199: page_87_table_1
# Dimensions: 17 rows x 10 columns
# Cell count: 161
# Has headers: False
#
# Table 200: page_88_table_0
# Dimensions: 5 rows x 3 columns
# Cell count: 12
# Has headers: False
#
# Table 201: page_88_table_1
# Dimensions: 16 rows x 10 columns
# Cell count: 151
# Has headers: False
#
# Table 202: page_89_table_0
# Dimensions: 5 rows x 3 columns
# Cell count: 12
# Has headers: False
#
# Table 203: page_89_table_1
# Dimensions: 17 rows x 10 columns
# Cell count: 161
# Has headers: False
#
# Table 204: page_90_table_0
# Dimensions: 5 rows x 3 columns
# Cell count: 12
# Has headers: False
#
# Table 205: page_90_table_1
# Dimensions: 16 rows x 10 columns
# Cell count: 151
# Has headers: False
#
# Table 206: page_91_table_0
# Dimensions: 5 rows x 3 columns
# Cell count: 12
# Has headers: False
#
# Table 207: page_91_table_1
# Dimensions: 14 rows x 10 columns
# Cell count: 131
# Has headers: False
#
# Table 208: page_92_table_0
# Dimensions: 5 rows x 3 columns
# Cell count: 12
# Has headers: False
#
# Table 209: page_92_table_1
# Dimensions: 16 rows x 8 columns
# Cell count: 128
# Has headers: False
#
# Table 210: page_93_table_0
# Dimensions: 5 rows x 3 columns
# Cell count: 12
# Has headers: False
#
# Table 211: page_93_table_1
# Dimensions: 16 rows x 8 columns
# Cell count: 128
# Has headers: False
#
# Table 212: page_94_table_0
# Dimensions: 5 rows x 3 columns
# Cell count: 12
# Has headers: False
#
# Table 213: page_94_table_1
# Dimensions: 16 rows x 8 columns
# Cell count: 128
# Has headers: False
#
# Table 214: page_95_table_0
# Dimensions: 15 rows x 5 columns
# Cell count: 26
# Has headers: False
#
# Table 215: page_95_table_1
# Dimensions: 5 rows x 3 columns
# Cell count: 12
# Has headers: False
#
# Table 216: page_96_table_0
# Dimensions: 5 rows x 3 columns
# Cell count: 12
# Has headers: False
#
# Table 217: page_96_table_1
# Dimensions: 9 rows x 9 columns
# Cell count: 57
# Has headers: False
#
# Table 218: page_96_table_2
# Dimensions: 5 rows x 5 columns
# Cell count: 21
# Has headers: False
#
# Table 219: page_97_table_0
# Dimensions: 5 rows x 3 columns
# Cell count: 12
# Has headers: False
#
# Table 220: page_97_table_1
# Dimensions: 3 rows x 4 columns
# Cell count: 12
# Has headers: False
#
# Table 221: page_97_table_2
# Dimensions: 7 rows x 4 columns
# Cell count: 25
# Has headers: False
#
# Table 222: page_98_table_0
# Dimensions: 5 rows x 3 columns
# Cell count: 12
# Has headers: False
#
# Table 223: page_98_table_1
# Dimensions: 13 rows x 2 columns
# Cell count: 26
# Has headers: False
#
# Table 224: page_99_table_0
# Dimensions: 5 rows x 3 columns
# Cell count: 12
# Has headers: False
#
# Table 225: page_99_table_1
# Dimensions: 3 rows x 5 columns
# Cell count: 15
# Has headers: False
#
# Table 226: page_100_table_0
# Dimensions: 5 rows x 3 columns
# Cell count: 12
# Has headers: False
#
# Table 227: page_100_table_1
# Dimensions: 3 rows x 2 columns
# Cell count: 6
# Has headers: False
#
# Table 228: page_100_table_2
# Dimensions: 21 rows x 4 columns
# Cell count: 68
# Has headers: False
#
# Table 229: page_101_table_0
# Dimensions: 5 rows x 3 columns
# Cell count: 12
# Has headers: False
#
# Table 230: page_101_table_1
# Dimensions: 22 rows x 4 columns
# Cell count: 71
# Has headers: False
#
# Table 231: page_102_table_0
# Dimensions: 5 rows x 3 columns
# Cell count: 12
# Has headers: False
#
# Table 232: page_102_table_1
# Dimensions: 13 rows x 4 columns
# Cell count: 51
# Has headers: False
#
# Table 233: page_103_table_0
# Dimensions: 5 rows x 3 columns
# Cell count: 12
# Has headers: False
#
# Table 234: page_103_table_1
# Dimensions: 2 rows x 4 columns
# Cell count: 8
# Has headers: False
#
# Table 235: page_103_table_2
# Dimensions: 11 rows x 6 columns
# Cell count: 61
# Has headers: False
#
# Table 236: page_104_table_0
# Dimensions: 5 rows x 3 columns
# Cell count: 12
# Has headers: False
#
# Table 237: page_104_table_1
# Dimensions: 19 rows x 4 columns
# Cell count: 70
# Has headers: False
#
# Table 238: page_105_table_0
# Dimensions: 5 rows x 3 columns
# Cell count: 12
# Has headers: False
#
# Table 239: page_105_table_1
# Dimensions: 20 rows x 5 columns
# Cell count: 100
# Has headers: False
#
# Table 240: page_106_table_0
# Dimensions: 5 rows x 3 columns
# Cell count: 12
# Has headers: False
#
# Table 241: page_106_table_1
# Dimensions: 19 rows x 5 columns
# Cell count: 95
# Has headers: False
#
# Table 242: page_107_table_0
# Dimensions: 5 rows x 3 columns
# Cell count: 12
# Has headers: False
#
# Table 243: page_107_table_1
# Dimensions: 4 rows x 4 columns
# Cell count: 16
# Has headers: False
#
# Table 244: page_107_table_2
# Dimensions: 2 rows x 2 columns
# Cell count: 4
# Has headers: False
#
# Table 245: page_108_table_0
# Dimensions: 5 rows x 3 columns
# Cell count: 12
# Has headers: False
#
# Table 246: page_108_table_1
# Dimensions: 14 rows x 5 columns
# Cell count: 60
# Has headers: False
#
# Table 247: page_109_table_0
# Dimensions: 5 rows x 3 columns
# Cell count: 12
# Has headers: False
#
# Table 248: page_109_table_1
# Dimensions: 16 rows x 6 columns
# Cell count: 64
# Has headers: False
#
# Table 249: page_110_table_0
# Dimensions: 5 rows x 3 columns
# Cell count: 12
# Has headers: False
#
# Table 250: page_110_table_1
# Dimensions: 5 rows x 4 columns
# Cell count: 20
# Has headers: False
#
# Table 251: page_111_table_0
# Dimensions: 5 rows x 3 columns
# Cell count: 12
# Has headers: False
#
# Table 252: page_111_table_1
# Dimensions: 12 rows x 5 columns
# Cell count: 60
# Has headers: False
#
# Table 253: page_112_table_0
# Dimensions: 5 rows x 3 columns
# Cell count: 12
# Has headers: False
#
# Table 254: page_112_table_1
# Dimensions: 10 rows x 5 columns
# Cell count: 47
# Has headers: False
#
# Table 255: page_113_table_0
# Dimensions: 5 rows x 3 columns
# Cell count: 12
# Has headers: False
#
# Table 256: page_113_table_1
# Dimensions: 12 rows x 10 columns
# Cell count: 55
# Has headers: False
#
# Table 257: page_114_table_0
# Dimensions: 5 rows x 3 columns
# Cell count: 12
# Has headers: False
#
# Table 258: page_114_table_1
# Dimensions: 10 rows x 10 columns
# Cell count: 52
# Has headers: False
#
# Table 259: page_115_table_0
# Dimensions: 5 rows x 3 columns
# Cell count: 12
# Has headers: False
#
# Table 260: page_115_table_1
# Dimensions: 8 rows x 4 columns
# Cell count: 32
# Has headers: False
#
# Table 261: page_116_table_0
# Dimensions: 5 rows x 3 columns
# Cell count: 12
# Has headers: False
#
# Table 262: page_116_table_1
# Dimensions: 6 rows x 10 columns
# Cell count: 33
# Has headers: False
#
# Table 263: page_117_table_0
# Dimensions: 5 rows x 3 columns
# Cell count: 12
# Has headers: False
#
# Table 264: page_117_table_1
# Dimensions: 6 rows x 10 columns
# Cell count: 33
# Has headers: False
#
# Table 265: page_117_table_2
# Dimensions: 2 rows x 2 columns
# Cell count: 4
# Has headers: False
#
# Table 266: page_118_table_0
# Dimensions: 5 rows x 3 columns
# Cell count: 12
# Has headers: False
#
# Table 267: page_118_table_1
# Dimensions: 20 rows x 3 columns
# Cell count: 27
# Has headers: False
#
# Table 268: page_119_table_0
# Dimensions: 5 rows x 3 columns
# Cell count: 12
# Has headers: False
#
# Table 269: page_119_table_1
# Dimensions: 24 rows x 6 columns
# Cell count: 120
# Has headers: False
#
# Table 270: page_120_table_0
# Dimensions: 5 rows x 3 columns
# Cell count: 12
# Has headers: False
#
# Table 271: page_120_table_1
# Dimensions: 27 rows x 6 columns
# Cell count: 124
# Has headers: False
#
# Table 272: page_121_table_0
# Dimensions: 5 rows x 3 columns
# Cell count: 12
# Has headers: False
#
# Table 273: page_121_table_1
# Dimensions: 26 rows x 6 columns
# Cell count: 123
# Has headers: False
#
# Table 274: page_122_table_0
# Dimensions: 5 rows x 3 columns
# Cell count: 12
# Has headers: False
#
# Table 275: page_122_table_1
# Dimensions: 6 rows x 4 columns
# Cell count: 24
# Has headers: False
#
# Table 276: page_122_table_2
# Dimensions: 2 rows x 2 columns
# Cell count: 4
# Has headers: False

# %%
    # Display the first table
    print("\n\nDetailed view of first table:")
    first_table_id = list(results['formatted_tables'].keys())[0]
    first_table = results['formatted_tables'][first_table_id]['with_headers']
    first_table_headers = set(results['table_metadata'][first_table_id]['header_positions'])
    display_dataframe(first_table, first_table_headers)

    # Extract tables from page 31
    print("\n\nExtracted tables from page 31:")
    page_31_tables = extract_specific_page_tables(sample_data, 31)
    print(f"Found {len(page_31_tables)} tables on page 31")

    # Display each table from page 31
    for i, table in enumerate(page_31_tables):
        print(f"\nPage 31 Table {i+3}:")
        df, headers = format_table_with_headers(table)
        display_dataframe(df, headers)
# Out:
# Detailed view of first table:
# +----+-----------------+--------------------------------------------+------------+------------+-----------+
# |    | 0               | 1                                          | 2          | 3          | 4         |
# +====+=================+============================================+============+============+===========+
# |  0 | amneal          | BATCH MANUFACTURING RECORD                 |            |            |           |
# +----+-----------------+--------------------------------------------+------------+------------+-----------+
# |  1 | NAME OF PRODUCT | Multiple Electrolytes Injection Type 1 USP |            |            | BATCH NO. |
# +----+-----------------+--------------------------------------------+------------+------------+-----------+
# |  2 | FILLING LINE    | BAG LINE (LINE-2)                          | PAGE NO.   | I OF I     | AH230017  |
# +----+-----------------+--------------------------------------------+------------+------------+-----------+
# |  3 | BMR NO.         | BMR-PA-048-02                              | BATCH SIZE | 4000 L/    |           |
# +----+-----------------+--------------------------------------------+------------+------------+-----------+
# |  4 | PACK SIZE       | 500 mL                                     |            | 3960 kg/   |           |
# |    |                 |                                            |            | 7606 Units |           |
# +----+-----------------+--------------------------------------------+------------+------------+-----------+
#
#
# Extracted tables from page 31:
# Found 3 tables on page 31
#
# Page 31 Table 3:
# +----+-----------------+--------------------------------------------+-----------+
# |    | 0               | 1                                          | 2         |
# +====+=================+============================================+===========+
# |  0 | amneal          | BATCH MANUFACTURING RECORD                 |           |
# +----+-----------------+--------------------------------------------+-----------+
# |  1 | NAME OF PRODUCT | Multiple Electrolytes Injection Type 1 USP | BATCH NO. |
# +----+-----------------+--------------------------------------------+-----------+
# |  2 | BMR NO.         | BMR-PA-048-02                              | AH230017  |
# +----+-----------------+--------------------------------------------+-----------+
# |  3 | BATCH SIZE      | 4000 L/ 3960 kg/7606 Units                 |           |
# +----+-----------------+--------------------------------------------+-----------+
# |  4 | PAGE NO.        | Page 30 of 119                             |           |
# +----+-----------------+--------------------------------------------+-----------+
#
# Page 31 Table 4:
# +----+---------+-----------------------+---------------+-------------+------------+---------------+--------------------+-------------------------------+---------------------------+
# |    | 0       | 1                     | 2             | 3           | 4          | 5             | 6                  | 7                             | 8                         |
# +====+=========+=======================+===============+=============+============+===============+====================+===============================+===========================+
# |  0 | Sr. No. | Ingredients           | Material code | A.R. No.    | Balance ID | Qty. Required | Quantity Dispensed | Done By (SM/ MM) (Sign/ Date) | Ckd. by (SM) (Sign/ Date) |
# +----+---------+-----------------------+---------------+-------------+------------+---------------+--------------------+-------------------------------+---------------------------+
# |  1 | 1.      | Hydrochloric Acid IP* | RMI- 0388     | ARM21 00008 | EQPIPIl    | 10.11 g       | 10.1100 gm         | 02-may-23                     | 02.muy-23                 |
# |    |         |                       |               |             | PRO1154    |               |                    | :selected:                    | :selected:                |
# +----+---------+-----------------------+---------------+-------------+------------+---------------+--------------------+-------------------------------+---------------------------+
#
# Page 31 Table 5:
# +----+---------+------------------------+---------------+------------+------------+----------------+--------------------+---------------------------+---------------------------+
# |    | 0       | 1                      | 2             | 3          | 4          | 5              | 6                  | 7                         | 8                         |
# +====+=========+========================+===============+============+============+================+====================+===========================+===========================+
# |  0 | Sr. No. | Ingredients            | Material code | A.R. No.   | Balance ID | Qty. Required  | Quantity Dispensed | Done By (SM) (Sign/ Date) | Ckd. by (SM) (Sign/ Date) |
# +----+---------+------------------------+---------------+------------+------------+----------------+--------------------+---------------------------+---------------------------+
# |  1 | 1.      | Water for Injection IP | WIH-0004      | WF2305 033 |            | q.s. to 4000 L |                    | 5. 03-May-23              | I 03-May-23               |
# |    |         |                        |               |            |            |                |                    | :selected:                | :selected:                |
# +----+---------+------------------------+---------------+------------+------------+----------------+--------------------+---------------------------+---------------------------+
# |  2 | 2.      | Nitrogen               | RMI-0082      | 23001214   |            | q.s.           |                    | 5h 03-May-23              | 03-may-23                 |
# |    |         |                        |               |            |            |                |                    |                           | :selected:                |
# +----+---------+------------------------+---------------+------------+------------+----------------+--------------------+---------------------------+---------------------------+
